# %%
import pandas as pd 
data = pd.read_excel('Toothgrowthdata.xlsx')
print(data)
# Out:
#      len supp  dose
# 0    4.2   VC   0.5
# 1   11.5   VC   0.5
# 2    7.3   VC   0.5
# 3    5.8   VC   0.5
# 4    6.4   VC   0.5
# 5   10.0   VC   0.5
# 6   11.2   VC   0.5
# 7   11.2   VC   0.5
# 8    5.2   VC   0.5
# 9    7.0   VC   0.5
# 10  16.5   VC   1.0
# 11  16.5   VC   1.0
# 12  15.2   VC   1.0
# 13  17.3   VC   1.0
# 14  22.5   VC   1.0
# 15  17.3   VC   1.0
# 16  13.6   VC   1.0
# 17  14.5   VC   1.0
# 18  18.8   VC   1.0
# 19  15.5   VC   1.0
# 20  23.6   VC   2.0
# 21  18.5   VC   2.0
# 22  33.9   VC   2.0
# 23  25.5   VC   2.0
# 24  26.4   VC   2.0
# 25  32.5   VC   2.0
# 26  26.7   VC   2.0
# 27  21.5   VC   2.0
# 28  23.3   VC   2.0
# 29  29.5   VC   2.0
# 30  15.2   OJ   0.5
# 31  21.5   OJ   0.5
# 32  17.6   OJ   0.5
# 33   9.7   OJ   0.5
# 34  14.5   OJ   0.5
# 35  10.0   OJ   0.5
# 36   8.2   OJ   0.5
# 37   9.4   OJ   0.5
# 38  16.5   OJ   0.5
# 39   9.7   OJ   0.5
# 40  19.7   OJ   1.0
# 41  23.3   OJ   1.0
# 42  23.6   OJ   1.0
# 43  26.4   OJ   1.0
# ...

# %%
data.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000
